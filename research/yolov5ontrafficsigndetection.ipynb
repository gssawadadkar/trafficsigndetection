# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!python -m pip install --upgrade pip

#!pip install tensorflow==2.3.1

#!pip install tensorboard==2.4.1
# !pip install Ipython
# !pip install torch  #YOLOv5 runs on top of PyTorch, so we need to import it to the notebook
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.3 MB/s eta 0:00:00
# ...

# %%
import torch # YOLOv5 implemented using pytorch

# %%
from IPython.display import Image #this is to render predictions

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16003, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 16003 (delta 21), reused 20 (delta 13), pack-reused 15967
# Receiving objects: 100% (16003/16003), 14.66 MiB | 19.67 MiB/s, done.
# Resolving deltas: 100% (10983/10983), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.3/617.3 kB 37.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Divide the dataset in train and val folder.

# %%
import os
from random import choice
import shutil

#arrays to store file names
imgs =[]
xmls =[]

#setup dir names
trainPath = 'D:/yolov5_traffic_sign_detection/dataset/images/train'
valPath = 'D:/yolov5_traffic_sign_detection/dataset/images/val'
crsPath = 'D:/yolov5_traffic_sign_detection/data/ts/' #dir where images and annotations stored

#setup ratio (val ratio = rest of the files in origin dir after splitting into train and test)
train_ratio = 0.8
val_ratio = 0.2


#total count of imgs
totalImgCount = len(os.listdir(crsPath))/2

#soring files to corresponding arrays
for (dirname, dirs, files) in os.walk(crsPath):
    for filename in files:
        if filename.endswith('.txt'):
            xmls.append(filename)
        else:
            imgs.append(filename)


#counting range for cycles
countForTrain = int(len(imgs)*train_ratio)
countForVal = int(len(imgs)*val_ratio)
print("training images are : ",countForTrain)
print("Validation images are : ",countForVal)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-02aa87371138> in <cell line: 20>()
#      18
#      19 #total count of imgs
# ---> 20 totalImgCount = len(os.listdir(crsPath))/2
#      21
#      22 #soring files to corresponding arrays
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/yolov5_traffic_sign_detection/data/ts/'

# %%
from random import choice
import shutil, sys
trainimagePath = 'C:\\Users\\gssaw\\satellite_images\\yolov5_traffic_sign_detection\\dataset\\images\\train'
trainlabelPath = 'C:\\Users\\gssaw\\satellite_images\\yolov5_traffic_sign_detection\\dataset\\labels\\train'
valimagePath = 'C:\\Users\\gssaw\\satellite_images\\yolov5_traffic_sign_detection\\dataset\\images\\val'
vallabelPath = 'C:\\Users\\gssaw\\satellite_images\\yolov5_traffic_sign_detection\\dataset\\labels\\val'
#cycle for train dir
import os

dir_path = 'C:/Users/gssaw/satellite_images/yolov5_traffic_sign_detection/dataset/train/images'
# countForTrain=len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])
import os

# folder path
# dir_path = r'E:\account'
count = 0
# Iterate directory
for path in os.listdir(dir_path):
    # check if current path is a file
    if os.path.isfile(os.path.join(dir_path, path)):
        count += 1
print('File count:', count)

for x in range(count):

    fileJpg = choice(dir_path) # get name of random image from origin dir
    fileXml = fileJpg[:-4] +'.txt' # get name of corresponding annotation file

    #move both files into train dir
    #shutil.move(os.path.join(crsPath, fileJpg), os.path.join(trainimagePath, fileJpg))
    #shutil.move(os.path.join(crsPath, fileXml), os.path.join(trainlabelPath, fileXml))
    # shutil.copy(os.path.join(crsPath, fileJpg), os.path.join(trainimagePath, fileJpg))
    # shutil.copy(os.path.join(crsPath, fileXml), os.path.join(trainlabelPath, fileXml))


    #remove files from arrays
    # imgs.remove(fileJpg)
    # xmls.remove(fileXml)



#cycle for test dir
for x in range(count):
    import glob, random
    file_path_type = [f"{dir_path}*.png", f"{dir_path}*.jpeg"]
    imgs = glob.glob(random.choice(file_path_type))
    imgs = random.choice(images)

    fileJpg = choice(imgs) # get name of random image from origin dir
    fileXml = fileJpg[:-4] +'.txt' # get name of corresponding annotation file

    #move both files into train dir
    #shutil.move(os.path.join(crsPath, fileJpg), os.path.join(valimagePath, fileJpg))
    #shutil.move(os.path.join(crsPath, fileXml), os.path.join(vallabelPath, fileXml))
#     shutil.copy(os.path.join(crsPath, fileJpg), os.path.join(valimagePath, fileJpg))
#     shutil.copy(os.path.join(crsPath, fileXml), os.path.join(vallabelPath, fileXml))

#     #remove files from arrays
#     imgs.remove(fileJpg)
#     xmls.remove(fileXml)

# #rest of files will be validation files, so rename origin dir to val dir
# #os.rename(crsPath, valPath)
# shutil.move(crsPath, valPath)
# Out:
# File count: 1392
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [31], in <cell line: 43>()
#      46 imgs = glob.glob(random.choice(file_path_type))
#      47 # imgs = random.choice(images)
# ---> 49 fileJpg = choice(imgs) # get name of random image from origin dir
#      50 fileXml = fileJpg[:-4] +'.txt'
#
# File ~\anaconda3\lib\random.py:346, in Random.choice(self, seq)
#     344 """Choose a random element from a non-empty sequence."""
#     345 # raises IndexError if seq is empty
# --> 346 return seq[self._randbelow(len(seq))]
#
# IndexError: list index out of range

# %% [markdown]
# # Create dataset.yaml
#
# ### move the dataset’s dataset.yaml file to the /content/yolov5/data directory.
# ### This file contains information required by YOLO to train the model on the custom data.
#
# ![image.png](attachment:image.png)

# %%
# !python train.py --img 415 --batch 16 --epochs 30 --data dataset.yaml --weights yolov5s.pt --cache
# Out:
# Traceback (most recent call last):
#   File "C:\Users\gssaw\satellite_images\yolov5_traffic_sign_detection\yolov5\train.py", line 35, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## At the end of the training, two files should be saved in yolov5/runs/train/exp/weights: last.pt and best.pt. We’ll use best.pt.
#
# ## Explore the metrics recorded during training, I suggest you use TensorBoard, a very interactive exploration tool:

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 16660), started 3:38:43 ago. (Use '!kill 16660' to kill it.)
#       <iframe id="tensorboard-frame-4c93fc9761d2346a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4c93fc9761d2346a");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Let’s explore now how confident our model is. We can plot a validation batch obtained during training and inspect the confidence score of each label

# %%
Image(filename='runs/train/exp2/test_batch2_pred.jpg', width=1000)

# %% [markdown]
# Training losses and performance metrics are also logged to Tensorboard and a custom results.txt logfile which is plotted as results.png (below) after training completes.

# %% [markdown]
# You’ll be implementing the detect.py script with the best.pt weights and image dimensions of 416x416 pixels (it’s really important to comply with that). The results will be saved to runs/detect/exp. To display the results, run the following code:

# %%
#!python detect.py --source runs/train/exp/testimg.jpg --weights runs/train/exp/weights/best.pt --conf 0.25

# !python detect.py --source runs/train/exp2/a.jpg --weights best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='runs/train/exp2/a.jpg', update=False, view_img=False, weights=['best.pt'])
# image 1/1 D:\yolov5_traffic_sign_detection\yolov5\runs\train\exp2\a.jpg: 384x640 2 speed limits, Done. (0.141s)
# Results saved to runs\detect\exp4
# Done. (0.193s)
# YOLOv5  v5.0-41-g4890499 torch 1.8.1+cpu CPU
#
# Fusing layers...
# Model Summary: 224 layers, 7062001 parameters, 0 gradients, 16.4 GFLOPS

# %%
Image(filename='runs/detect/exp4/a.jpg', width=416)

# %%
from utils.plots import plot_results
plot_results(save_dir='runs/train/exp2')  # plot results.txt as results.png

# %%
pwd
# Out:
# 'C:\\Users\\gssaw\\satellite_images\\yolov5_traffic_sign_detection\\yolov5'

# %%
# !nvidia-smi
# Out:
# Thu Oct  5 09:55:43 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
import gdown
url="https://drive.google.com/file/d/1AtkDACgdxD-7cISTAfiRA-4nIJ-q1F8T/view?usp=drive_link"
file_id=url.split("/")
file_id=file_id[-2]
file_id
# Out:
# '1AtkDACgdxD-7cISTAfiRA-4nIJ-q1F8T'

# %%
prefix="https://drive.google.com/uc?/export=download&id="
gdown.download(prefix+file_id)
# Out:
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=1AtkDACgdxD-7cISTAfiRA-4nIJ-q1F8T
# To: /content/traffic_data.zip
# 100%|██████████| 41.6M/41.6M [00:00<00:00, 159MB/s]
# 'traffic_data.zip'

# %%
# !unzip traffic_data.zip
# !rm -rf traffic_data.zip
# Out:
# Archive:  traffic_data.zip
#   inflating: data.yaml
#    creating: train/images/
#   inflating: train/images/000001_jpg.rf.4f8eac6747a989e40bff9c86bc5d97be.jpg
#   inflating: train/images/000002_jpg.rf.0fbb15854c0866ff8449b3f32f9dd0e5.jpg
#   inflating: train/images/000003_jpg.rf.c1648de205c62fdabbc0d5b2847d1678.jpg
#   inflating: train/images/000004_jpg.rf.9f73e13e1faf84f71c433c0abdf66082.jpg
#   inflating: train/images/000005_jpg.rf.a8431952a2d4dc5463f8f93919fa2201.jpg
#   inflating: train/images/000006_jpg.rf.811eeb60e95036a6568a73583f8b52e9.jpg
#   inflating: train/images/000007_jpg.rf.b958df8b62a80169e152c04a22a473e6.jpg
#   inflating: train/images/000008_jpg.rf.d555e4c027b57cf20f6751c919fd5560.jpg
#   inflating: train/images/000010_jpg.rf.042de156c5a8ce96c1e84f7faa7aa080.jpg
#   inflating: train/images/000011_jpg.rf.53c6ff6282ac9b62a265b2ea801004be.jpg
#   inflating: train/images/000014_jpg.rf.0e994901b99fdf20b511ad8212547292.jpg
# ...

# %%
# this is the yaml file we are loading into this notebook with our data
# %cat data.yaml
# Out:
# names:
# - Cycle Zone
# - Danger Ahead
# - Deer Zone
# - End of Right Road -Go straight-
# - Give Way
# - Go Left or Straight
# - Go Right or Straight
# - Go Straight
# - Huddle Road
# - Left Curve Ahead
# - Left Sharp Curve
# - No Entry
# - No Over Taking Trucks
# - No Over Taking
# - No Stopping
# - No Waiting
# - Pedestrian
# - Right Curve Ahead
# - Right Sharp Curve
# - Road Work
# - RoundAbout
# - Slippery Road
# - Snow Warning Sign
# - Speed Limit 100
# - Speed Limit 120
# - Speed Limit 20
# - Speed Limit 30
# - Speed Limit 50
# - Speed Limit 60
# - Speed Limit 70
# - Speed Limit 80
# - Stop
# - Traffic Signals Ahead
# - Truck Sign
# - Turn Left
# - Turn Right
# nc: 36
# train: ../train/images
# val: ../valid/images

# %%
# based on number of classes based on yaml

import yaml
with open("data.yaml","r") as file:
  num_classes=str(yaml.safe_load(file)["nc"])

# %%
num_classes
# Out:
# '36'

# %%
# this is the model configuration we will use
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, AGPL-3.0 license
#
# # Parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
# ...

# %%
# customize ipython writefile as we can write variable
from IPython.core.magic import register_line_cell_magic
@register_line_cell_magic
def writetemplate(line,cell):
  with open(line, "w") as f:
    f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc:{num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
# Train Custom YOLOv5 Detector

# %%
from ctypes import pointer
next we will train the models

* img:- define input image size
* batch :- determine batch size
* epochs: define the number of training epochs (Note: ofter 3000+ are common here)
* data :- set the path to our yaml file
* cfg:- specify our model configuration
* weight: specify a custom path to weights (you can download weighjts from ultralytics google drive)
* name : result name
* nosave : only save the final check point
* cache: - cache images for faster training
# Out:
#   File "<ipython-input-70-31aac01c6536>", line 2
#     next we will train the models
#          ^
# SyntaxError: invalid syntax

# %%
# train yolov5s on custom data for 200 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 50 --data '../data.yaml' --cfg ./models/yolov5s.yaml --weights 'yolov5s.pt' --name yolov5s_results --cache
# Out:
# /content/yolov5
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=../data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# Evaluate Custom YOLOv5 Detector Performance

# %%
# start tensorboard
# launch you have started training
# logs save in the folder runs
# %reload_ext tensorboard
# !kill 26615
# %tensorboard --logdir runs

# %%
# we can also output some older school graphs if the tensorboard is not working
# !pip install utils
from IPython.display import Image, display

# Display the image
display(Image(filename="./yolov5/runs/train/yolov5s_results10/results.png", width=1000))

# %%
pwd
# Out:
# '/content'

# %%
print("Ground truth training data ")
Image(filename="/content/yolov5/runs/train/yolov5s_results10/val_batch0_labels.jpg",width=1000)
# Out:
# Ground truth training data

# %%
print("Ground truth augmented training data ")
Image(filename="/content/yolov5/runs/train/yolov5s_results10/train_batch0.jpg",width=1000)
# Out:
# Ground truth augmented training data

# %%
# Run inference with trained weights
# traineds weights are saved by default in our weights folder
# %ls yolov5/runs
# Out:
# train/

# %%
# %ls /content/yolov5/runs/train/yolov5s_results10/weights
# Out:
# best.pt  last.pt

# %%
# %cd /content/yolov5/
# !python detect.py --weights /content/yolov5/runs/train/yolov5s_results10/weights/best.pt --img 416 --conf 0.5 --source ../valid/images
# Out:
# /content/yolov5
# detect: weights=['/content/yolov5/runs/train/yolov5s_results10/weights/best.pt'], source=../valid/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7107217 parameters, 0 gradients, 16.1 GFLOPs
# image 1/173 /content/valid/images/000013_jpg.rf.e763f3f682368260571870394697890f.jpg: 416x416 1 Speed Limit 30, 7.5ms
# image 2/173 /content/valid/images/000017_jpg.rf.45cfcf29b1fab2ddef197150c9435692.jpg: 416x416 1 Speed Limit 30, 7.5ms
# ...
